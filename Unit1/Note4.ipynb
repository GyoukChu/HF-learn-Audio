# %%
# !pip install -q datasets huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n)
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
# Data Streaming
# Pros: no disk space requirements for any size of data
from datasets import load_dataset
gigaspeech = load_dataset("speechcolab/gigaspeech", "xs", streaming=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1454: FutureWarning: The repository for speechcolab/gigaspeech contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/speechcolab/gigaspeech
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...

# %%
gigaspeech["train"][0] # Error occurs. No longer access individual sampmles
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-770332a6a2e8> in <cell line: 1>()
# ----> 1 gigaspeech["train"][0] # Error occurs. No longer access individual sampmles
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in __getitem__(self, index)
#      59
#      60     def __getitem__(self, index) -> T_co:
# ---> 61         raise NotImplementedError("Subclasses of Dataset should implement __getitem__.")
#      62
#      63     # def __getitems__(self, indices: List) -> List[T_co]:
#
# NotImplementedError: Subclasses of Dataset should implement __getitem__.

# %%
next(iter(gigaspeech["train"])) # No error. We have to iterate over dataset
# Out:
# {'segment_id': 'YOU0000000315_S0000660',
#  'speaker': 'N/A',
#  'text': "AS THEY'RE LEAVING <COMMA> CAN KASH PULL ZAHRA ASIDE REALLY QUICKLY <QUESTIONMARK>",
#  'audio': {'path': 'xs_chunks_0000/YOU0000000315_S0000660.wav',
#   'array': array([0.0005188 , 0.00085449, 0.00012207, ..., 0.00125122, 0.00076294,
#          0.00036621]),
#   'sampling_rate': 16000},
#  'begin_time': 2941.89,
#  'end_time': 2945.07,
#  'audio_id': 'YOU0000000315',
#  'title': 'Return to Vasselheim | Critical Role: VOX MACHINA | Episode 43',
#  'url': 'https://www.youtube.com/watch?v=zr2n1fLVasU',
#  'source': 2,
#  'category': 24,
#  'original_full_path': 'audio/youtube/P0004/YOU0000000315.opus'}

# %%
# Preview several examples from streaming dataset
gigaspeech_head = gigaspeech["train"].take(2)
list(gigaspeech_head)
# Out:
# [{'segment_id': 'YOU0000000315_S0000660',
#   'speaker': 'N/A',
#   'text': "AS THEY'RE LEAVING <COMMA> CAN KASH PULL ZAHRA ASIDE REALLY QUICKLY <QUESTIONMARK>",
#   'audio': {'path': 'xs_chunks_0000/YOU0000000315_S0000660.wav',
#    'array': array([0.0005188 , 0.00085449, 0.00012207, ..., 0.00125122, 0.00076294,
#           0.00036621]),
#    'sampling_rate': 16000},
#   'begin_time': 2941.89,
#   'end_time': 2945.07,
#   'audio_id': 'YOU0000000315',
#   'title': 'Return to Vasselheim | Critical Role: VOX MACHINA | Episode 43',
#   'url': 'https://www.youtube.com/watch?v=zr2n1fLVasU',
#   'source': 2,
#   'category': 24,
#   'original_full_path': 'audio/youtube/P0004/YOU0000000315.opus'},
#  {'segment_id': 'AUD0000001043_S0000775',
#   'speaker': 'N/A',
#   'text': 'SIX TOMATOES <PERIOD>',
#   'audio': {'path': 'xs_chunks_0000/AUD0000001043_S0000775.wav',
#    'array': array([ 1.43432617e-03,  1.37329102e-03,  1.31225586e-03, ...,
# ...
